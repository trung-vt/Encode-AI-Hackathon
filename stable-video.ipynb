# %%
# from transformers import AutoModelForSeq2SeqLM, AutoTokenizer


# model_name = "stabilityai/stable-video-diffusion-img2vid-xt"
# model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
# tokenizer = AutoTokenizer.from_pretrained(model_name)

# # Now you can use the model and tokenizer for your task


from diffusers import DiffusionPipeline

pipeline = DiffusionPipeline.from_pretrained("stabilityai/stable-video-diffusion-img2vid-xt")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/transformers/utils/import_utils.py:1390, in _LazyModule._get_module(self, module_name)
#    1389 try:
# -> 1390     return importlib.import_module("." + module_name, self.__name__)
#    1391 except Exception as e:
#
# File ~/opt/anaconda3/lib/python3.9/importlib/__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:850, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/transformers/models/clip/image_processing_clip.py:21
#      19 import numpy as np
# ---> 21 from ...image_processing_utils import BaseImageProcessor, BatchFeature, get_size_dict
#      22 from ...image_transforms import (
#      23     convert_to_rgb,
#      24     get_resize_output_image_size,
#      25     resize,
#      26     to_channel_dimension_format,
#      27 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/transformers/image_processing_utils.py:28
#      27 from .feature_extraction_utils import BatchFeature as BaseBatchFeature
# ---> 28 from .image_transforms import center_crop, normalize, rescale
#      29 from .image_utils import ChannelDimension
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/transformers/image_transforms.py:47
#      46 if is_tf_available():
# ---> 47     import tensorflow as tf
#      49 if is_flax_available():
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/__init__.py:38
#      36 import typing as _typing
# ---> 38 from tensorflow.python.tools import module_util as _module_util
#      39 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/__init__.py:37
#      36 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow
# ---> 37 from tensorflow.python.eager import context
#      39 # pylint: enable=wildcard-import
#      40
#      41 # Bring in subpackages.
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/context.py:36
#      35 from tensorflow.python.eager import cancellation
# ---> 36 from tensorflow.python.eager import execute
#      37 from tensorflow.python.eager import executor
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:21
#      20 from tensorflow.python.eager import core
# ---> 21 from tensorflow.python.framework import dtypes
#      22 from tensorflow.python.framework import tensor_conversion_registry
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/dtypes.py:38
#      36 from tensorflow.python.framework import cpp_shape_inference_pb2
# ---> 38 _np_bfloat16 = pywrap_bfloat16.bfloat16_type()
#      39 _np_float8_e4m3fn = _pywrap_float8.TF_float8_e4m3fn_type()
#
# TypeError: Unable to convert function return value to a Python type! The signature was
# 	() -> handle
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/diffusers/utils/import_utils.py:704, in _LazyModule._get_module(self, module_name)
#     703 try:
# --> 704     return importlib.import_module("." + module_name, self.__name__)
#     705 except Exception as e:
#
# File ~/opt/anaconda3/lib/python3.9/importlib/__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:850, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/diffusers/pipelines/stable_video_diffusion/pipeline_stable_video_diffusion.py:22
#      21 import torch
# ---> 22 from transformers import CLIPImageProcessor, CLIPVisionModelWithProjection
#      24 from ...image_processor import VaeImageProcessor
#
# File <frozen importlib._bootstrap>:1055, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/transformers/utils/import_utils.py:1381, in _LazyModule.__getattr__(self, name)
#    1380     module = self._get_module(self._class_to_module[name])
# -> 1381     value = getattr(module, name)
#    1382 else:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/transformers/utils/import_utils.py:1380, in _LazyModule.__getattr__(self, name)
#    1379 elif name in self._class_to_module.keys():
# -> 1380     module = self._get_module(self._class_to_module[name])
#    1381     value = getattr(module, name)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/transformers/utils/import_utils.py:1392, in _LazyModule._get_module(self, module_name)
#    1391 except Exception as e:
# -> 1392     raise RuntimeError(
#    1393         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1394         f" traceback):\n{e}"
#    1395     ) from e
#
# RuntimeError: Failed to import transformers.models.clip.image_processing_clip because of the following error (look up to see its traceback):
# Unable to convert function return value to a Python type! The signature was
# 	() -> handle
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# /Users/t/Documents/GIT/Encode-AI-Hackathon/stable-video.ipynb Cell 1 line 1
#       <a href='vscode-notebook-cell:/Users/t/Documents/GIT/Encode-AI-Hackathon/stable-video.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> # from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
#       <a href='vscode-notebook-cell:/Users/t/Documents/GIT/Encode-AI-Hackathon/stable-video.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a>
#       <a href='vscode-notebook-cell:/Users/t/Documents/GIT/Encode-AI-Hackathon/stable-video.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a>
#    (...)
#       <a href='vscode-notebook-cell:/Users/t/Documents/GIT/Encode-AI-Hackathon/stable-video.ipynb#W0sZmlsZQ%3D%3D?line=6'>7</a>
#       <a href='vscode-notebook-cell:/Users/t/Documents/GIT/Encode-AI-Hackathon/stable-video.ipynb#W0sZmlsZQ%3D%3D?line=7'>8</a> # # Now you can use the model and tokenizer for your task
#      <a href='vscode-notebook-cell:/Users/t/Documents/GIT/Encode-AI-Hackathon/stable-video.ipynb#W0sZmlsZQ%3D%3D?line=10'>11</a> from diffusers import DiffusionPipeline
# ---> <a href='vscode-notebook-cell:/Users/t/Documents/GIT/Encode-AI-Hackathon/stable-video.ipynb#W0sZmlsZQ%3D%3D?line=12'>13</a> pipeline = DiffusionPipeline.from_pretrained("stabilityai/stable-video-diffusion-img2vid-xt")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/huggingface_hub/utils/_validators.py:118, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     115 if check_use_auth_token:
#     116     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 118 return fn(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/diffusers/pipelines/pipeline_utils.py:1111, in DiffusionPipeline.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1106     if pretrained_model_name_or_path.count("/") > 1:
#    1107         raise ValueError(
#    1108             f'The provided pretrained_model_name_or_path "{pretrained_model_name_or_path}"'
#    1109             " is neither a valid local path nor a valid repo id. Please check the parameter."
#    1110         )
# -> 1111     cached_folder = cls.download(
#    1112         pretrained_model_name_or_path,
#    1113         cache_dir=cache_dir,
#    1114         resume_download=resume_download,
#    1115         force_download=force_download,
#    1116         proxies=proxies,
#    1117         local_files_only=local_files_only,
#    1118         token=token,
#    1119         revision=revision,
#    1120         from_flax=from_flax,
#    1121         use_safetensors=use_safetensors,
#    1122         use_onnx=use_onnx,
#    1123         custom_pipeline=custom_pipeline,
#    1124         custom_revision=custom_revision,
#    1125         variant=variant,
#    1126         load_connected_pipeline=load_connected_pipeline,
#    1127         **kwargs,
#    1128     )
#    1129 else:
#    1130     cached_folder = pretrained_model_name_or_path
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/huggingface_hub/utils/_validators.py:118, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     115 if check_use_auth_token:
#     116     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 118 return fn(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/diffusers/pipelines/pipeline_utils.py:1783, in DiffusionPipeline.download(cls, pretrained_model_name, **kwargs)
#    1776     raise ValueError(
#    1777         f"The repository for {pretrained_model_name} contains custom code in {'.py, '.join([os.path.join(k, v) for k,v in custom_components.items()])} which must be executed to correctly "
#    1778         f"load the model. You can inspect the repository content at {', '.join([f'https://hf.co/{pretrained_model_name}/{k}/{v}.py' for k,v in custom_components.items()])}.\n"
#    1779         f"Please pass the argument `trust_remote_code=True` to allow custom code to be run."
#    1780     )
#    1782 # retrieve passed components that should not be downloaded
# -> 1783 pipeline_class = _get_pipeline_class(
#    1784     cls,
#    1785     config_dict,
#    1786     load_connected_pipeline=load_connected_pipeline,
#    1787     custom_pipeline=custom_pipeline,
#    1788     repo_id=pretrained_model_name if load_pipe_from_hub else None,
#    1789     hub_revision=revision,
#    1790     class_name=custom_class_name,
#    1791     cache_dir=cache_dir,
#    1792     revision=custom_revision,
#    1793 )
#    1794 expected_components, _ = cls._get_signature_keys(pipeline_class)
#    1795 passed_components = [k for k in expected_components if k in kwargs]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/diffusers/pipelines/pipeline_utils.py:401, in _get_pipeline_class(class_obj, config, load_connected_pipeline, custom_pipeline, repo_id, hub_revision, class_name, cache_dir, revision)
#     395     raise ValueError(
#     396         "The class name could not be found in the configuration file. Please make sure to pass the correct `class_name`."
#     397     )
#     399 class_name = class_name[4:] if class_name.startswith("Flax") else class_name
# --> 401 pipeline_cls = getattr(diffusers_module, class_name)
#     403 if load_connected_pipeline:
#     404     from .auto_pipeline import _get_connected_pipeline
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/diffusers/utils/import_utils.py:695, in _LazyModule.__getattr__(self, name)
#     693 elif name in self._class_to_module.keys():
#     694     module = self._get_module(self._class_to_module[name])
# --> 695     value = getattr(module, name)
#     696 else:
#     697     raise AttributeError(f"module {self.__name__} has no attribute {name}")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/diffusers/utils/import_utils.py:695, in _LazyModule.__getattr__(self, name)
#     693 elif name in self._class_to_module.keys():
#     694     module = self._get_module(self._class_to_module[name])
# --> 695     value = getattr(module, name)
#     696 else:
#     697     raise AttributeError(f"module {self.__name__} has no attribute {name}")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/diffusers/utils/import_utils.py:694, in _LazyModule.__getattr__(self, name)
#     692     value = self._get_module(name)
#     693 elif name in self._class_to_module.keys():
# --> 694     module = self._get_module(self._class_to_module[name])
#     695     value = getattr(module, name)
#     696 else:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/diffusers/utils/import_utils.py:706, in _LazyModule._get_module(self, module_name)
#     704     return importlib.import_module("." + module_name, self.__name__)
#     705 except Exception as e:
# --> 706     raise RuntimeError(
#     707         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#     708         f" traceback):\n{e}"
#     709     ) from e
#
# RuntimeError: Failed to import diffusers.pipelines.stable_video_diffusion.pipeline_stable_video_diffusion because of the following error (look up to see its traceback):
# Failed to import transformers.models.clip.image_processing_clip because of the following error (look up to see its traceback):
# Unable to convert function return value to a Python type! The signature was
# 	() -> handle
